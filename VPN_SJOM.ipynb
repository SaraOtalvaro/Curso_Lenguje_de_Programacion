# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraOtalvaro/Curso_Lenguje_de_Programacion/blob/main/VPN_SJOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **¿Qué es el valor Presente Neto?**
#
# El valor presente neto (VPN) es el valor de los flujos de efectivo proyectados, descontados al presente. Es un método de modelado financiero utilizado por los contadores para la elaboración de presupuestos de capital y por analistas e inversores para evaluar la rentabilidad de las inversiones y proyectos propuestos.
#
# ## **Método del valor presente neto**
#
# El método del valor presente neto incorpora el valor del dinero en determinado tiempo de flujos de efectivo netos de un negocio o proyecto. El objetivo del valor presente neto es realizar las comparaciones entre los periodos en los que el proyecto o negocio tuvo diferentes flujos de efectivo para determinar si conviene o no invertir en él.
#
# El valor depende de la tasa de interés a la que se ajusta el cálculo del valor presente neto. El método para calcular el valor presente neto es con una razón aritmética, en donde el numerador es el dinero y el denominador corresponde a la tasa de interés.
#
# ### **Formula del Valor Presente Neto (VPN)**
#
# $$
# VPN = \sum_{t=1}^{n} \frac{F_t}{(1 + r)^t} - I
# $$
#
# Donde:
# - **\( F_t \)** = Flujo de caja neto en el periodo \(t \).
# - **\( r \)** = Tasa de descuentos.
# - **\( t \)** = Número de periodos.
# - **\( I \)** = Inversion inicial.
#
# ---
# #### *Ejemplo de Cálculo del VPN*
#
#  Supongamos una inversión inicial de **$10,000** con una tasa de descuento del **8%** y los siguientes flujos de caja:
#
#  | Año | Flujo de Caja |
#  |---- | ----------|
#  | 1 | $5,000    |
#     | 2 | $3,000    |
#       | 3 | $8,000    |
#
# #### *Paso 1: Calcular los valores presentes de los flujos de caja*
#
# $$
# \text{Año 1:} \frac{5000}{(1 + 0.08)^1} = 4,629
# $$
#
# $$
# \text{Año 2:} \frac{3000}{(1 + 0.08)^2} = 2,572
# $$
#
# $$
# \text{Año 3:} \frac{8000}{(1 + 0.08)^3} = 6,349
# $$
#
# #### *Paso 2: Sumar los valores presentes de los flujos de caja*
#
# $$
# 4,629 + 2,572 + 6,349 = 13,550
# $$
#
# #### *Paso 3: Calcular el VPN final*
#
# $$
# VPN = 13,550 - 10,000 = 3,550
# $$
#
# ---
#
# ### **Conclusión**
#
# Dado que el **VPN es positivo (\$3,550)**, la inversión **es rentable**.
#
# **Nota:** El VPN es una herramienta clave para evaluar si un proyecto generará ganancias netas. Se utiliza en sector bancario, inversión y también en las finanzas personales.
#
# **Ventajas del uso del VPN:**
#
# *Considera el valor del dinero en el tiempo.
# * Permite comparar diferentes proyectos de inversión.
# *Facilita la toma de decisiones informadas.
#
# **Desventajas del uso de la VPN:**
#
# *Requiere estimaciones precisas de los flujos de caja futuros y la tasa de desceuntos.
# *Puede ser complejo de calcular sin herramientas adecuadas.
# *No considera factores cualitativos que podrían influir en la decisión de inversión.
# *Para facilitar el cálculo del VPN y los márgenes de utilidad de tus proyectos.

# %% [markdown]
# [Referencia](https://blog.hubspot.es/sales/que-es-valor-presente-neto)
#
# 1. Elemento de lista
# 2. Elemento de lista

# %%
Inversión_inicial = 10000
flujo_año_1 = 5000
flujo_año_2 = 3000
flujo_año_3 = 8000
tasa_descuento = 0.08

# %%
VPN = flujo_año_1 / (1 + tasa_descuento) + (flujo_año_2 / (1 + tasa_descuento)**2) + (flujo_año_3 / (1 + tasa_descuento)**3 - Inversión_inicial)
print(VPN)
# Out:
# 3552.3040186963362

# %%
 if VPN > 0:
    print("La inversión es rentable")
else:
    print("La inversión no es rentable")
# Out:
# La inversión es rentable
